# %%
# %matplotlib inline

# %%
# http://macvector.com/MacVector/agarosegelsimulation.html

# %%
from pydna.gel import Gel

# %%
from pydna.genbank import genbank

# %%
pBR322 = genbank("J01749")

# %%
from Bio.Restriction import BglI

# %%
pBR322_bgl = pBR322.cut(BglI)

# %%
from pydna.gel import weight_standards, weight_standard_sample

# %%
standard = weight_standard_sample(key="1kb+_GeneRuler")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-acd0f0f3d016> in <module>()
# ----> 1 standard = weight_standard_sample(key="1kb+_GeneRuler")
#
# ~/python_packages/pydna/pydna/gel.py in weight_standard_sample(key, qty)
#     439     fracs = weight_standards[key]['percent']
#     440     quantities = qty * fracs
# --> 441     return gen_sample(sizes, quantities)
#     442
#     443
#
# ~/python_packages/pydna/pydna/gel.py in gen_sample(sizes, quantities)
#     429         quantities = lin_div_Qty(frags, quantities, criteria=len)
#     430     return [_Dseqrecord(seq, n=quantities[i]/seq.mw()) for i, seq in
# --> 431             enumerate(frags)]
#     432
#     433
#
# ~/python_packages/pydna/pydna/gel.py in <listcomp>(.0)
#     428     if not hasattr(quantities, '__iter__'):
#     429         quantities = lin_div_Qty(frags, quantities, criteria=len)
# ...

# %%
Gel([standard,pBR322_bgl])

# %%
from pydna.dseqrecord import Dseqrecord as Dsr

# %%
standard2 = [Dsr("N"*500), Dsr("N"*1000), Dsr("N"*1500), Dsr("N"*2000),]

# %%
Gel([standard2, [Dsr("N"*1200)]]).run(wellx =20)
